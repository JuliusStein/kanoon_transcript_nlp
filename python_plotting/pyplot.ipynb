# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
caseFrame = pd.read_json('../data_cleaning/formattedData_noText.json')

# %%
caseFrame.head()
# Out:
#                                                title        tid  \
# 0  Madan Gopal Kakkad vs Naval Dubey And Anr on 2...    1314858
# 1  Santhosh Madhavan @ Amrutha ... vs Circle Insp...    1815206
# 2  Atender Yadav vs State Govt Of Nct Of Delhi on...  151172763
# 3   Beeru vs State Nct Of Delhi on 11 December, 2013   13922091
# 4    State Of Haryana vs Anil Kumar on 11 July, 2003    1076070
#
#                        court        date                      judge  \
# 0     Supreme Court of India  1992-04-29   Bench: Pandian, S.R. (J)
# 1          Kerala High Court  2008-07-21                    unknown
# 2           Delhi High Court  2013-10-29    Author: Kailash Gambhir
# 3           Delhi High Court  2013-12-11    Author: Kailash Gambhir
# 4  Punjab-Haryana High Court  2003-07-11  Bench: S Nijjar, S Grewal
#
#    resolution dressMentioned resultCode dressCode
# 0  Conviction             No          C         N
# 1     Neither            Yes          U         Y
# 2   acquittal             No          A         N
# 3   Acquittal             No          A         N
# 4  Conviction            Yes          C         Y

# %%
import datetime as dt
import numpy as np
from matplotlib.pyplot import figure

fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')


for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970):
        if(row['resultCode'] != "U"):
            try:
                plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
            except:
                print("Y:",year,"M:",month,"D:",day,"failed")

annot_x = (plt.xlim()[1] + plt.xlim()[0])/2
annot_y = (plt.ylim()[1] + plt.ylim()[0])/2

txt = frame1.text(annot_x, annot_y, "Chart Ready", 
              ha='center', fontsize=36, color='#DD4012')

def hover(event):
    txt.set_text("")

fig.canvas.mpl_connect("motion_notify_event", hover)
plt.show()

#fig.savefig('fig1.png', dpi=200)

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970):
        if(row['resultCode'] != "U"):
            if(row['dressCode'] == "Y"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

#fig.savefig('fig2.png', dpi=200)

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970):
        if(row['resultCode'] != "U"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

#fig.savefig('fig3.png', dpi=200)

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970):
        if(row['resultCode'] != "U" and row['dressCode'] == "Y"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

#fig.savefig('fig4.png', dpi=200)

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970):
        if(row['resultCode'] != "U" and row['dressCode'] == "N"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

#fig.savefig('fig5.png', dpi=200)

# %%
import datetime as dt
import numpy as np
from matplotlib.pyplot import figure

fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')
frame1.set_xlim([dt.datetime(2001, 1, 1), dt.datetime(2021, 12, 31)])

count = 0
for index, row in caseFrame.iterrows():
    if(index%5 == 0):
        date = row['date']
        year, month, day = map(int,date.split("-"))
        if(year>2000):
            if(row['resultCode'] != "U"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5) # ,linestyle='--', dashes=(160, 15))
                    count += 1
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()
print(count)

fig.savefig('fig1_2000_ds.svg')
# Out:
# 760

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')
frame1.set_xlim([dt.datetime(2001, 1, 1), dt.datetime(2021, 12, 31)])

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970 and index%5 == 0):
        if(row['resultCode'] != "U"):
            if(row['dressCode'] == "Y"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="grey",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            elif(row['dressCode'] == "N"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
                

plt.show()

fig.savefig('fig2_2000_ds.svg')

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')
frame1.set_xlim([dt.datetime(2001, 1, 1), dt.datetime(2021, 12, 31)])


for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970 and index%5 == 0):
        if(row['resultCode'] != "U"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="crimson",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

fig.savefig('fig3_2000_ds.svg', dpi=200)

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')
frame1.set_xlim([dt.datetime(2001, 1, 1), dt.datetime(2021, 12, 31)])


for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970 and index%5==0):
        if(row['resultCode'] != "U" and row['dressCode'] == "Y"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

fig.savefig('fig4_2000_ds.svg')

# %%
fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')
frame1.set_xlim([dt.datetime(2001, 1, 1), dt.datetime(2021, 12, 31)])

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970 and index%5 == 0):
        if(row['resultCode'] != "U" and row['dressCode'] == "N"):
            if(row['resultCode'] == "A"):
                try:
                    plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
            else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=0.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")

plt.show()

fig.savefig('fig5_2000_ds.svg')

# %%
import datetime as dt
import numpy as np
from matplotlib.pyplot import figure

fig = plt.gcf()
fig.set_size_inches(24, 13.6)
frame1 = fig.gca()
frame1.axes.get_yaxis().set_visible(False)
frame1.set_facecolor((0, 0, 0))
fig.patch.set_facecolor('xkcd:black')
frame1.spines['bottom'].set_color('white')
frame1.xaxis.label.set_color('white')
frame1.tick_params(axis='x', colors='white')

northCourts = ['Jammu & Kashmir High Court','Delhi High Court - Orders',  'Delhi District Court', 'Allahabad High Court','Rajasthan High Court','Delhi High Court','Uttarakhand High Court','Jammu & Kashmir High Court - Srinagar Bench', 'Himachal Pradesh High Court','Punjab-Haryana High Court']
southCourts = ['Bangalore District Court', 'Andhra Pradesh High Court - Amravati','Karnataka High Court','Andhra High Court', 'Kerala High Court','Madras High Court', 'Telangana High Court']
eastCourts = ['Sikkim High Court','Tripura High Court','Gauhati High Court', 'Calcutta High Court','Calcutta High Court (Appellete Side)','Patna High Court','Patna High Court - Orders', 'Jharkhand High Court','Orissa High Court', 'High Court of Meghalaya', 'Manipur High Court',]
westCourts = ['Bombay High Court','Gujarat High Court', 'Rajasthan High Court - Jodhpur']
centralCourts = ['Madhya Pradesh High Court','Chattisgarh High Court']
nationalCourts = ['Supreme Court of India', 'Supreme Court - Daily Orders']

for index, row in caseFrame.iterrows():
    date = row['date']
    year, month, day = map(int,date.split("-"))
    if(year>1970 and index%5==0):
        if(row['resultCode'] != "U" and row['court'] in nationalCourts):
#             if(row['resultCode'] == "A"):
#                 try:
#                     plt.axvline(dt.datetime(year, month, day), color="red",linewidth=0.5)
#                 except:
#                     print("Y:",year,"M:",month,"D:",day,"failed")
#             else:
                try:
                    plt.axvline(dt.datetime(year, month, day), color="white",linewidth=1.5)
                except:
                    print("Y:",year,"M:",month,"D:",day,"failed")
                
plt.show()

fig.savefig('fig6_2000_Sup.svg')

# %%
caseFrame['court'].unique()
# Out:
# array(['Supreme Court of India', 'Kerala High Court', 'Delhi High Court',
#        'Punjab-Haryana High Court', 'Bombay High Court',
#        'Karnataka High Court', 'Gujarat High Court', 'Gauhati High Court',
#        'Madras High Court', 'Rajasthan High Court - Jodhpur',
#        'Delhi District Court', 'Patna High Court', 'Allahabad High Court',
#        'Patna High Court - Orders', 'Himachal Pradesh High Court',
#        'Madhya Pradesh High Court', 'Tripura High Court',
#        'Chattisgarh High Court', 'Calcutta High Court (Appellete Side)',
#        'Jammu & Kashmir High Court', 'High Court of Meghalaya',
#        'Sikkim High Court', 'Telangana High Court', 'Orissa High Court',
#        'Andhra Pradesh High Court - Amravati',
#        'Delhi High Court - Orders', 'Jharkhand High Court',
#        'Bangalore District Court', 'Rajasthan High Court',
#        'Calcutta High Court', 'Uttarakhand High Court',
#        'Supreme Court - Daily Orders', 'Manipur High Court',
#        'Jammu & Kashmir High Court - Srinagar Bench', 'Andhra High Court'],
#       dtype=object)

# %%
northCases = []
for index, row in caseFrame.iterrows():
    if row['court'] in northCourts:
        northCases.append(row['court'])

import collections
counter = collections.Counter(northCases)
caseCounts = dict(counter)
caseCounts["Delhi High Court"] += (caseCounts["Delhi High Court - Orders"])
#del caseCounts["Delhi District Court"]
del caseCounts["Delhi High Court - Orders"]
caseCounts['Jammu & Kashmir High Court'] += caseCounts['Jammu & Kashmir High Court - Srinagar Bench']
del caseCounts['Jammu & Kashmir High Court - Srinagar Bench']

caseCountsSorted = dict(sorted(caseCounts.items(), key=lambda item: item[1], reverse=False))
caseCountsSorted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d5a788cfcb4> in <module>
#       1 northCases = []
# ----> 2 for index, row in caseFrame.iterrows():
#       3     if row['court'] in northCourts:
#       4         northCases.append(row['court'])
#       5
#
# NameError: name 'caseFrame' is not defined

# %%
d = caseCountsSorted
plt.barh(range(len(d)), d.values(), align='center', color='grey')
plt.yticks(range(len(d)), d.keys())

fig = plt.gcf()
fig.set_size_inches(10, 6)

plt.show()
fig.savefig('northCourts.svg')
